# %%
import pandas as pd
import bar_chart_race as bcr

df = pd.read_csv("modern_RAPTOR_by_player.csv")
df.head()
# Out:
#         player_name  player_id  season  poss    mp  raptor_box_offense  \
# 0      Alex Abrines  abrinal01    2017  2387  1135            0.745505
# 1      Alex Abrines  abrinal01    2018  2546  1244            0.317549
# 2      Alex Abrines  abrinal01    2019  1279   588           -3.215683
# 3  Precious Achiuwa  achiupr01    2021  1581   749           -4.122966
# 4        Quincy Acy    acyqu01    2014  1716   847           -1.716079
#
#    raptor_box_defense  raptor_box_total  raptor_onoff_offense  \
# 0           -0.372938          0.372567             -0.418553
# 1           -1.725325         -1.407776             -1.291727
# 2            1.078399         -2.137285             -6.158856
# 3            1.359278         -2.763688             -4.050779
# 4            0.133115         -1.582964             -0.324811
#
#    raptor_onoff_defense  ...  raptor_offense  raptor_defense  raptor_total  \
# 0             -3.857011  ...        0.543421       -1.144832     -0.601411
# ...

# %%
new_df = df.pivot_table("poss", index="season", columns="player_name")
new_df.head()
# Out:
# player_name  AJ Hammons  AJ Price  Aaron Brooks  Aaron Gordon  Aaron Gray  \
# season
# 2014                NaN     210.0        3238.0           NaN       721.0
# 2015                NaN     629.0        3956.0        1603.0         NaN
# 2016                NaN       NaN        2256.0        3823.0         NaN
# 2017              329.0       NaN        1819.0        4687.0         NaN
# 2018                NaN       NaN         404.0        3994.0         NaN
#
# player_name  Aaron Harrison  Aaron Holiday  Aaron Jackson  Aaron Nesmith  \
# season
# 2014                    NaN            NaN            NaN            NaN
# 2015                    NaN            NaN            NaN            NaN
# 2016                  222.0            NaN            NaN            NaN
# 2017                   34.0            NaN            NaN            NaN
# 2018                  480.0            NaN          102.0            NaN
#
# ...

# %%
bcr.bar_chart_race(new_df.head())
# Out:
# /home/unix/anaconda3/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /home/unix/anaconda3/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /home/unix/anaconda3/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /home/unix/anaconda3/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /home/unix/anaconda3/lib/python3.9/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...
